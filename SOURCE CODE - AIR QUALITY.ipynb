# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd # import pandas library

df = pd.read_csv("/content/air quality data.csv")

# %%
print(df)
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  01-01-2015    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  02-01-2015    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  03-01-2015    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  04-01-2015    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  05-01-2015    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  27-06-2020  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  28-06-2020  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  29-06-2020  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  30-06-2020  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  01-07-2020  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         29531 non-null  object
#  1   Date         29531 non-null  object
#  2   PM2.5        24933 non-null  float64
#  3   PM10         18391 non-null  float64
#  4   NO           25949 non-null  float64
#  5   NO2          25946 non-null  float64
#  6   NOx          25346 non-null  float64
#  7   NH3          19203 non-null  float64
#  8   CO           27472 non-null  float64
#  9   SO2          25677 non-null  float64
#  10  O3           25509 non-null  float64
#  11  Benzene      23908 non-null  float64
#  12  Toluene      21490 non-null  float64
#  13  Xylene       11422 non-null  float64
#  14  Unnamed: 14  24850 non-null  float64
#  15  Unnamed: 15  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df.isnull().sum()
# Out:
# City               0
# Date               0
# PM2.5           4598
# PM10           11140
# NO              3582
# NO2             3585
# NOx             4185
# NH3            10328
# CO              2059
# SO2             3854
# O3              4022
# Benzene         5623
# Toluene         8041
# Xylene         18109
# Unnamed: 14     4681
# Unnamed: 15     4681
# dtype: int64

# %%
df.head(6)
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  01-01-2015    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  02-01-2015    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  03-01-2015    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  04-01-2015    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  05-01-2015    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
# 5  Ahmedabad  06-01-2015    NaN   NaN  45.41  38.48  81.50  NaN  45.41  45.76
#
#        O3  Benzene  Toluene  Xylene  Unnamed: 14 Unnamed: 15
# 0  133.36     0.00     0.02    0.00          NaN         NaN
# 1   34.06     3.68     5.50    3.77          NaN         NaN
# 2   30.70     6.80    16.40    2.25          NaN         NaN
# 3   36.08     4.43    10.14    1.00          NaN         NaN
# 4   39.31     7.01    18.89    2.78          NaN         NaN
# ...

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
data2=df.copy()

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         29531 non-null  object
#  1   Date         29531 non-null  object
#  2   PM2.5        24933 non-null  float64
#  3   PM10         18391 non-null  float64
#  4   NO           25949 non-null  float64
#  5   NO2          25946 non-null  float64
#  6   NOx          25346 non-null  float64
#  7   NH3          19203 non-null  float64
#  8   CO           27472 non-null  float64
#  9   SO2          25677 non-null  float64
#  10  O3           25509 non-null  float64
#  11  Benzene      23908 non-null  float64
#  12  Toluene      21490 non-null  float64
#  13  Xylene       11422 non-null  float64
#  14  Unnamed: 14  24850 non-null  float64
#  15  Unnamed: 15  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
dist = list(data2['City'])
distset = set(dist)
# Removing potential NaN values from the set before creating the dictionary
distset = {x for x in distset if pd.notna(x)}
dd = list(distset)
dict0fWords = {dd[i]: i for i in range(0, len(dd))}
data2['City'] = data2['City'].map(dict0fWords)
#The second mapping is likely redundant and has been removed.

# %%
data2.isnull().sum()
# Out:
# City           29531
# Date               0
# PM2.5           4598
# PM10           11140
# NO              3582
# NO2             3585
# NOx             4185
# NH3            10328
# CO              2059
# SO2             3854
# O3              4022
# Benzene         5623
# Toluene         8041
# Xylene         18109
# Unnamed: 14     4681
# Unnamed: 15     4681
# dtype: int64

# %%
data2.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')
